# %%
import DSGRN
import DSGRN_utils
import numpy as np
import json

import time
from matplotlib.colors import ListedColormap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import DSGRN
#       2 import DSGRN_utils
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'DSGRN'

# %% [markdown]
# ## Figure 1: Toggle Switch

# %%
net_spec = """v1 : ~v2
              v2 : ~v1 """

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameter nodes:', parameter_graph.size())
# Out:
# Number of parameter nodes: 9

# %%
par_index = 4

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 3.31 ms, sys: 603 μs, total: 3.91 ms
# Wall time: 3.97 ms

# %%
G = DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
type(morse_graph)
# Out:
# pychomp.DirectedAcyclicGraph.DirectedAcyclicGraph

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)

# %% [markdown]
# ## Figure 2:

# %%
net_spec = """v1 : v1+v2
              v2 : ~v1 """

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameter nodes:', parameter_graph.size())
# Out:
# Number of parameter nodes: 120

# %%
bool_params = DSGRN.boolean_parameters(parameter_graph)

print('Number of boolean parameters:', len(bool_params))
# Out:
# Number of boolean parameters: 36

# %%
par_index = 4
parameter = parameter_graph.parameter(par_index)
print(DSGRN.parameter_input_polynomials(parameter, 0))
print(DSGRN.parameter_input_polynomials(parameter, 1))
# Out:
# p0 = (L[v1->v1] + L[v2->v1])
# p1 = (U[v1->v1] + L[v2->v1])
# p2 = (L[v1->v1] + U[v2->v1])
# p3 = (U[v1->v1] + U[v2->v1])
# p0 = L[v1->v2]
# p1 = U[v1->v2]

# %%
print(parameter.partialorders())
# Out:
# v1 : (p0, t0, p1, p2, p3, t1)
# v2 : (p0, p1, t0)

# %%
partial_orders = ['(p0, p1, p2, p3,t0, t1)','(p0, t0, p1)']

# %%
DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
# Out:
# 20

# %%
par_index = DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
# par_index = 4

parameter = parameter_graph.parameter(par_index)

# %%
# print(DSGRN.parameter_input_polynomials(parameter, 0))
# print(DSGRN.parameter_input_polynomials(parameter, 1))
# print(DSGRN.parameter_input_polynomials(parameter, 2))

# %%
# parameter.partialorders('T')

# %%
# sample_par_index = DSGRN.par_index_from_sample(parameter_graph, L, U, T)
# print(sample_par_index)
# sample_parameter = parameter_graph.parameter(sample_par_index)
# sample_parameter.inequalities()

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 8.71 ms, sys: 0 ns, total: 8.71 ms
# Wall time: 9.5 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)

# %% [markdown]
# ## Figure 3:

# %%
net_spec = """v1 : v1+v2
              v2 : (~v1) """

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameter nodes:', parameter_graph.size())
# Out:
# Number of parameter nodes: 120

# %%
bool_params = DSGRN.boolean_parameters(parameter_graph)

print('Number of boolean parameters:', len(bool_params))
# Out:
# Number of boolean parameters: 36

# %%
par_index = 4
parameter = parameter_graph.parameter(par_index)
print(DSGRN.parameter_input_polynomials(parameter, 0))
print(DSGRN.parameter_input_polynomials(parameter, 1))
# Out:
# p0 = (L[v1->v1] + L[v2->v1])
# p1 = (U[v1->v1] + L[v2->v1])
# p2 = (L[v1->v1] + U[v2->v1])
# p3 = (U[v1->v1] + U[v2->v1])
# p0 = L[v1->v2]
# p1 = U[v1->v2]

# %%
print(parameter.partialorders('T'))
# Out:
# v1 : (p0, T[v1->v1], p1, p2, p3, T[v1->v2])
# v2 : (p0, p1, T[v2->v1])

# %%
partial_orders = ['(p0, p2, t0, t1, p1, p3)','(p0, t0, p1)']

# %%
DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
# Out:
# 28

# %%
par_index = DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
# par_index = 4

parameter = parameter_graph.parameter(par_index)

# %%
# print(DSGRN.parameter_input_polynomials(parameter, 0))
# print(DSGRN.parameter_input_polynomials(parameter, 1))
# print(DSGRN.parameter_input_polynomials(parameter, 2))

# %%
# parameter.partialorders('T')

# %%
# sample_par_index = DSGRN.par_index_from_sample(parameter_graph, L, U, T)
# print(sample_par_index)
# sample_parameter = parameter_graph.parameter(sample_par_index)
# sample_parameter.inequalities()

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 4.91 ms, sys: 0 ns, total: 4.91 ms
# Wall time: 4.92 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)

# %%
for par_index in bool_params:
  parameter = parameter_graph.parameter(par_index)
  morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
  DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/DSGRN_utils/PlotMorseSets.py:260: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(fig_w, fig_h))

# %%
par_index = bool_params[7]
parameter = parameter_graph.parameter(par_index)
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)
print(parameter.partialorders())
# Out:
# v1 : (p0, p1, p2, t0, t1, p3)
# v2 : (p0, t0, p1)

# %% [markdown]
# ## Figure 4:

# %%
net_spec = """v1 : v1+v2
              v2 : (~v1)v2 """

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameter nodes:', parameter_graph.size())
# Out:
# Number of parameter nodes: 1600

# %%
bool_params = DSGRN.boolean_parameters(parameter_graph)

print('Number of boolean parameters:', len(bool_params))
# Out:
# Number of boolean parameters: 144

# %%
par_index = 4
parameter = parameter_graph.parameter(par_index)
print(DSGRN.parameter_input_polynomials(parameter, 0))
print(DSGRN.parameter_input_polynomials(parameter, 1))
# Out:
# p0 = (L[v1->v1] + L[v2->v1])
# p1 = (U[v1->v1] + L[v2->v1])
# p2 = (L[v1->v1] + U[v2->v1])
# p3 = (U[v1->v1] + U[v2->v1])
# p0 = L[v1->v2] L[v2->v2]
# p1 = U[v1->v2] L[v2->v2]
# p2 = L[v1->v2] U[v2->v2]
# p3 = U[v1->v2] U[v2->v2]

# %%
print(parameter.partialorders())
# Out:
# v1 : (p0, t0, p1, p2, p3, t1)
# v2 : (p0, p1, p2, p3, t0, t1)

# %%
partial_orders = ['(p0, p1, p2, t0, t1, p3)','(p0, p1, p2, t0, t1, p3)']

# %%
DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
# Out:
# 126

# %%
partial_orders = ['(p0, p1, p2, t0, t1, p3)','(p0, p1, p2, t0, t1, p3)']
par_index = DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 7.93 ms, sys: 0 ns, total: 7.93 ms
# Wall time: 8.25 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)

# %%
partial_orders = ['(p0, p1, p2, t1, t0, p3)','(p0, p1, p2, t0, t1, p3)']
par_index = DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 12.9 ms, sys: 0 ns, total: 12.9 ms
# Wall time: 14.3 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)

# %%
partial_orders = ['(p0, p1, p2, t0, t1, p3)','(p0, p1, p2, t1, t0, p3)']
par_index = DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 8.05 ms, sys: 1.01 ms, total: 9.06 ms
# Wall time: 9.16 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)

# %%
partial_orders = ['(p0, p1, p2, t1, t0, p3)','(p0, p1, p2, t1, t0, p3)']
par_index = DSGRN.index_from_partial_orders(parameter_graph, partial_orders)
parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 6.82 ms, sys: 0 ns, total: 6.82 ms
# Wall time: 6.83 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph,stg,graded_complex,cmap=ListedColormap(['white']),self_arrow_clr='blue',arrow_clr='black',plot_bdry_cells=False)
