# %% [markdown]
# ## Install the code

# %% [markdown]
# The DSGRN code is available at https://github.com/marciogameiro/DSGRN.git.
#
# The pyCHomP code is available at https://github.com/marciogameiro/pyCHomP2.git.
#
# The DSGRN code is used to manipulate the parameter graph of a network and the pyCHomP code is used to compute homology.
#
# The code to define the multivalued maps defined in the thesis and to compute the Conley-Morse graphs are available at https://github.com/marciogameiro/DSGRN_utils.git.
#
# This code will soon be included in the DSGRN package, but for the moment it is on a separate repository. The repositories above are not needed to use the code. All one needs to do is install the code using the commands below.

# %%
# Install DSGRN (and pyCHomP)
# %pip install DSGRN
# Out:
# Collecting DSGRN
#   Downloading dsgrn-1.9.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: graphviz>=0.20 in /usr/local/lib/python3.12/dist-packages (from DSGRN) (0.21)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from DSGRN) (3.10.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from DSGRN) (2.0.2)
# Requirement already satisfied: networkx>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from DSGRN) (3.5)
# Collecting pychomp2>=1.0.4 (from DSGRN)
#   Downloading pychomp2-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from pychomp2>=1.0.4->DSGRN) (1.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->DSGRN) (1.17.0)
# Downloading dsgrn-1.9.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 23.2 MB/s eta 0:00:00
# Downloading pychomp2-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: pychomp2, DSGRN
# Successfully installed DSGRN-1.9.1 pychomp2-1.1.1

# %%
# Install the rook field paper code
# %pip install git+https://github.com/marciogameiro/DSGRN_utils.git
# Out:
# Collecting git+https://github.com/marciogameiro/DSGRN_utils.git
#   Cloning https://github.com/marciogameiro/DSGRN_utils.git to /tmp/pip-req-build-246dgp7_
#   Running command git clone --filter=blob:none --quiet https://github.com/marciogameiro/DSGRN_utils.git /tmp/pip-req-build-246dgp7_
#   Resolved https://github.com/marciogameiro/DSGRN_utils.git to commit debffadaa7abb1188f5306943a78c4cdd475eae5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: DSGRN>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from DSGRN_utils==1.0.0) (1.9.1)
# Requirement already satisfied: pychomp2>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from DSGRN_utils==1.0.0) (1.1.1)
# Requirement already satisfied: graphviz>=0.20 in /usr/local/lib/python3.12/dist-packages (from DSGRN_utils==1.0.0) (0.21)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from DSGRN_utils==1.0.0) (3.10.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from DSGRN_utils==1.0.0) (2.0.2)
# Requirement already satisfied: networkx>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from DSGRN>=1.9.0->DSGRN_utils==1.0.0) (3.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->DSGRN_utils==1.0.0) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from pychomp2>=1.0.4->DSGRN_utils==1.0.0) (1.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->DSGRN_utils==1.0.0) (1.17.0)
# Building wheels for collected packages: DSGRN_utils
#   Building wheel for DSGRN_utils (pyproject.toml) ... done
#   Created wheel for DSGRN_utils: filename=dsgrn_utils-1.0.0-py3-none-any.whl size=29531 sha256=684cbc0b4a084380965d79b0901b055031294325e352de0922521621769ac153
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d3jpgsjy/wheels/00/fa/a0/57556b77083fc89302a7f7f3b85c1f4b3216eed0abc2e5ae29
# Successfully built DSGRN_utils
# Installing collected packages: DSGRN_utils
# Successfully installed DSGRN_utils-1.0.0

# %% [markdown]
# ## Import and run the code

# %%
import DSGRN
import DSGRN_utils

import random
import time

# %% [markdown]
# # 16.1 Identifying Global Dynamics and Global Bifurcations

# %% [markdown]
# ## Example 16.1.1

# %%
# Network specification is given by a string
net_spec = """1 : ~2
              2 : ~1"""

# Define the network
network = DSGRN.Network(net_spec)

# Plot the regulatory network obtained
DSGRN.DrawGraph(network)

# %%
# Define the parameter graph
parameter_graph = DSGRN.ParameterGraph(network)
print('Number of parameters nodes:', parameter_graph.size())
# Out:
# Number of parameters nodes: 9

# %%
# Pick a parameter index
par_index = 4

# Define the parameter
parameter = parameter_graph.parameter(par_index)

# %%
# Compute Conley-Morse graph
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
# Plot Morse graph
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
# Plot Morse sets (only works for 2-node networks (2D) at the moment)
# Dots indicate self edges (equilibrium cells)
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# ## Example 16.1.2

# %%
# Network specification is given by a string
net_spec = """1 : 1+2+3
              2 : (~1)(2+3)
              3 : (~2)(1+3)      """

# Define the network
network = DSGRN.Network(net_spec)

# Plot the regulatory network obtained
DSGRN.DrawGraph(network)

# %%
# Define the parameter graph
parameter_graph = DSGRN.ParameterGraph(network)
print('Number of parameters nodes:', parameter_graph.size())
# Out:
# Number of parameters nodes: 87280405632

# %%
# Pick a different parameter
par_index = 52718681992

parameter = parameter_graph.parameter(par_index)

# %%
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# # Section 16.2 Identifying Periodic Orbits

# %% [markdown]
# ## Example 16.2.1

# %%
net_spec = """1 : (1)(~2)(~3)
              2 : (~1)(2)
              3 : (~2)(3)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 3600000

# %%
par_index = 2472287

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: total: 78.1 ms
# Wall time: 87.4 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.2.2

# %%
net_spec = """
  1 : 1(~2)(~3)
  2 : (~1)(2)
  3 : (~2)(3)
  4 : (2)
  5 : (3)(4)(5)
"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 13608000000

# %%
par_index = 5103162287

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: total: 11.6 s
# Wall time: 11.8 s

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.2.3

# %%
net_spec = """
  1 : 1(~2)(~3)
  2 : (~1)(2)
  3 : (~2)(3)
"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 3600000

# %%
par_index =  2023186

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: total: 109 ms
# Wall time: 104 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# # Section 16.3 Global Semi-conjugacies

# %% [markdown]
# ## Example 16.3.1

# %%
net_spec = """1 : (~1)(~2)
              2 : (~1)(~2)
            """

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameters:', parameter_graph.size())
# Out:
# Number of parameters: 1600

# %%
par_index = 974

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 10.9 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# ## Example 16.3.2

# %%
net_spec = """
  1 : 1(~2)(~3)
  2 : (~1)(2)
  3 : (~2)(3)
"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameters:', parameter_graph.size())
# Out:
# Number of parameters: 3600000

# %%
par_index = 2472286

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: total: 109 ms
# Wall time: 87.3 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.3.3

# %%
net_spec = """
  1 : (~2)(~4)
  2 : (~3)(~5)
  3 : (1)(~3)(~6)
  4 : (~5)
  5 : (~2)(~4)(3)
  6 : (~3)(~5)
"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameters:', parameter_graph.size())
# Out:
# Number of parameters: 4429771960320

# %%
par_index = 2684686006

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter,level=2)
# Out:
# CPU times: total: 2min 42s
# Wall time: 2min 45s

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# # Section 16.4 Morse graphs that are not Morse representations

# %% [markdown]
# ## Example 16.4.1

# %%
# Network specification is given by a string
net_spec = """1 : 1 + 2
              2 : (~1) 2"""

# Define the network
network = DSGRN.Network(net_spec)

# Plot the regulatory network obtained
DSGRN.DrawGraph(network)

# %%
# Define the parameter graph
parameter_graph = DSGRN.ParameterGraph(network)
print('Number of parameters nodes:', parameter_graph.size())
# Out:
# Number of parameters nodes: 1600

# %%
# Pick a parameter index
par_index = 47

# Define the parameter
parameter = parameter_graph.parameter(par_index)

# %%
# Compute Conley-Morse graph
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
# Plot Morse graph
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
# Plot Morse sets (only works for 2-node networks (2D) at the moment)
# Dots indicate self edges (equilibrium cells)
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# ## Example 16.4.2

# %%
# Network specification is given by a string
net_spec = """1 : 1+2+3
              2 : (~1)(2+3)
              3 : (~2)(1+3)      """

# Define the network
network = DSGRN.Network(net_spec)

# Plot the regulatory network obtained
DSGRN.DrawGraph(network)

# %%
# Define the parameter graph
parameter_graph = DSGRN.ParameterGraph(network)
print('Number of parameters nodes:', parameter_graph.size())
# Out:
# Number of parameters nodes: 87280405632

# %%
# Pick a different parameter
par_index = 65571607721

parameter = parameter_graph.parameter(par_index)

# %%
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.4.3

# %%
# Network specification is given by a string
net_spec = """1 : 1+2+3
              2 : (~1)(2+3)
              3 : (~2)(1+3)      """

# Define the network
network = DSGRN.Network(net_spec)

# Plot the regulatory network obtained
DSGRN.DrawGraph(network)

# %%
# Define the parameter graph
parameter_graph = DSGRN.ParameterGraph(network)
print('Number of parameters nodes:', parameter_graph.size())
# Out:
# Number of parameters nodes: 87280405632

# %%
# Pick a different parameter
par_index = 52717613010

parameter = parameter_graph.parameter(par_index)

# %%
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.4.4

# %%
net_spec = """
  1 : (~2)(~4)
  2 : (~3)(~5)
  3 : (1)(~3)(~6)
  4 : (~5)
  5 : (~2)(~4)(3)
  6 : (~3)(~5)
"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameters:', parameter_graph.size())
# Out:
# Number of parameters: 4429771960320

# %%
par_index = 1739757491101

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter,level=2)
# Out:
# CPU times: total: 3min 2s
# Wall time: 3min 4s

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)
